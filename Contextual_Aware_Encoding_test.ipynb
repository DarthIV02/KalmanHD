# %%
from DatasetLoader_mine2 import DatasetLoader
import os
import numpy as np

# %%
parent = 'multipletimeseriesforecasting/preprocessed-data/'

path = os.path.join(parent, 'SanFranciscoTraffic/traffic_weekly_dataset.tsf')

dl = DatasetLoader('SanFranciscoTraffic', path)

matrix_1_original = dl.dataset_load_and_preprocess("original")
matrix_1_norm = dl.dataset_load_and_preprocess("normalized")
print(matrix_1_norm.shape)
# Out:
# ---------------------------------------------------
# Dataset name:  SanFranciscoTraffic
# Dataset contains missing values?  False
# --------------------------
# ---------------------------------------------------
# Dataset name:  SanFranciscoTraffic
# Dataset contains missing values?  False
# --------------------------
# (862, 104)

# %%
sample_len = int(matrix_1_norm.shape[1]*(0.15))
print("Sample_len total", sample_len)

np.random.seed(1)
sets = np.random.choice(matrix_1_norm.shape[1]-40, int(sample_len), replace=False)
sets_training, sets_validation, sets_testing = sets[:int(len(sets)*.75)], sets[int(len(sets)*.75):int(len(sets)*.8)], sets[int(len(sets)*.8):]
print(sets_training, sets_validation, sets_testing)
# Out:
# Sample_len total 15
# [24 39 52 27 44  2 21 62 41 50 38] [54] [35 26 57]

# %% [markdown]
# #### Encoding with just Bind

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, embeddings, cos_similarity, bind, multiset, hard_quantize

from scipy.special import softmax

import time

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, num_classes, size, levels):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.flatten = torch.nn.Flatten()
        self.position = embeddings.Random(size, d)
        self.value = embeddings.Level(levels, d)
        self.cluster = functional.random_hv(models, d)

    def encode(self, x): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        sample_hv = bind(self.position.weight, self.value(x))
        sample_hv = multiset(sample_hv)
        print(hard_quantize(sample_hv))
        return hard_quantize(sample_hv)

    def model_update(self, x, y): # update # y = no hv
        #x = torch.reshape(x, (1,d))
        confidence = np.transpose(softmax(cos_similarity(x, self.cluster))) # Compare input with cluster
        model_result = F.linear(x, self.M.type(torch.FloatTensor))
        update = self.M + (float(self.lr) * float(y - F.linear(confidence, model_result)) * x) # Model + alpha*(Error)*(x)
        #update = update.mean(0) # Mean by columns
        self.M = update.type(torch.FloatTensor) # New 
        # update cluster center?
        center = [num.item() for num in confidence].index(max(confidence).item())
        self.cluster[center] = self.cluster[center] + (1-max(confidence)) * x
        return center
        

    def forward(self, x):
        enc = torch.reshape(self.encode(x), (1,d))
        confidence = np.transpose(softmax(cos_similarity(self.cluster, enc))) # Compare input with cluster
        model_result = F.linear(enc, self.M).type(torch.FloatTensor)
        res = F.linear(confidence, model_result) # Multiply enc (x) * weights (Model) = Dot product
        return res # Return the resolutions

    def train(self, sets_training, matrix_1_norm, epochs):
        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for i in sets_training:
                samples = matrix_1_norm[:, i:i+20]
                labels = matrix_1_norm[:, i+20]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    sample = torch.tensor(samples[n, :])
                    samples_hv = self.encode(sample) # Encode the inputs
                    self.model_update(samples_hv, label) # Pass input and label to train
                    predictions_testing = self.forward(sample) # Pass samples from test to model (forward function)
                    pred.append(float(predictions_testing[0]))
                    labels_full.append(float(label.unsqueeze(dim=0)))

            print(f"Training root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in sets_testing:
            samples = matrix_1_norm[:, i:i+20]
            labels = matrix_1_norm[:, i+20]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample)
                pred.append(float(predictions[0]))
                labels_full.append(float(label.unsqueeze(dim=0)))

        print(
            f"Testing root mean squared error of testing {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
# Debuging by making sure that diffrent level hypervectors are being chosen - ALL CLEAR

model = MultiModel_With_NonLinear_Sin(2, 20, 6) # 1 class, 5
model.train(sets_training, matrix_1_norm, 1)
model.test(sets_validation, matrix_1_norm)
# Out:
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1., -1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1., -1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# ...
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1.,  1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1.,  1.,  ..., -1., -1., -1.])
# MAP([ 1., -1., -1.,  ..., -1., -1., -1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# MAP([-1., -1., -1.,  ..., -1., -1.,  1.])
# Testing root mean squared error of testing 0.142

# %%
# Changing number of level hypervectors

for i in range(1,50):
    print(i)
    model = MultiModel_With_NonLinear_Sin(2, 20, i) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
for i in range(50, 100, 10):
    print(i)
    model = MultiModel_With_NonLinear_Sin(2, 20, i) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
for i in range(100, 1100, 100):
    print(i)
    model = MultiModel_With_NonLinear_Sin(2, 20, i) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
# Out:
# 1
# Training root mean squared error of 0.202
# Testing root mean squared error of testing 0.346
# 2
# Training root mean squared error of 0.130
# Testing root mean squared error of testing 0.168
# 3
# Training root mean squared error of 0.129
# Testing root mean squared error of testing 0.169
# 4
# Training root mean squared error of 0.121
# Testing root mean squared error of testing 0.166
# 5
# Training root mean squared error of 0.118
# Testing root mean squared error of testing 0.160
# 6
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.143
# 7
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.152
# 8
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.150
# 9
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.147
# 10
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.157
# 11
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.149
# 12
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.150
# 13
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.152
# 14
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.147
# 15
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.148
# 16
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.149
# 17
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.152
# 18
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.148
# 19
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 20
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.152
# 21
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.156
# 22
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.148
# 23
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.151
# 24
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.151
# 25
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 26
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.148
# 27
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.151
# 28
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.151
# 29
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.149
# 30
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.151
# 31
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 32
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 33
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 34
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.152
# 35
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.151
# 36
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.152
# 37
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 38
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 39
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.147
# 40
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 41
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 42
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 43
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 44
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.147
# 45
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.148
# 46
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 47
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 48
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.146
# 49
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.153
# 50
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 60
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 70
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.152
# 80
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.151
# 90
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 100
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 200
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.148
# 300
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 400
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.146
# 500
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.153
# 600
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 700
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.151
# 800
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.149
# 900
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.151
# 1000
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150

# %% [markdown]
# #### Encoding with bind and permutation

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, embeddings, cos_similarity, bind, multiset, hard_quantize, permute

from scipy.special import softmax

import time

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, num_classes, size, levels):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.flatten = torch.nn.Flatten()
        self.position = embeddings.Random(size, d)
        self.value = embeddings.Level(levels, d)
        self.cluster = functional.random_hv(models, d)

    def encode(self, x): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        #x = self.flatten(x)
        sample_hv = bind(self.position.weight, self.value(x))
        for i, hv in enumerate(sample_hv):
            sample_hv[i] = permute(hv, shifts=i)
        sample_hv = multiset(sample_hv)
        return hard_quantize(sample_hv)

    def model_update(self, x, y): # update # y = no hv
        #x = torch.reshape(x, (1,d))
        confidence = np.transpose(softmax(cos_similarity(x, self.cluster))) # Compare input with cluster
        model_result = F.linear(x, self.M.type(torch.FloatTensor))
        update = self.M + (float(self.lr) * float(y - F.linear(confidence, model_result)) * x) # Model + alpha*(Error)*(x)
        #update = update.mean(0) # Mean by columns
        self.M = update.type(torch.FloatTensor) # New 
        # update cluster center?
        center = [num.item() for num in confidence].index(max(confidence).item())
        self.cluster[center] = self.cluster[center] + (1-max(confidence)) * x
        return center
        

    def forward(self, x):
        enc = torch.reshape(self.encode(x), (1,d))
        confidence = np.transpose(softmax(cos_similarity(self.cluster, enc))) # Compare input with cluster
        model_result = F.linear(enc, self.M).type(torch.FloatTensor)
        res = F.linear(confidence, model_result) # Multiply enc (x) * weights (Model) = Dot product
        return res # Return the resolutions

    def train(self, sets_training, matrix_1_norm, epochs):
        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for i in sets_training:
                samples = matrix_1_norm[:, i:i+20]
                labels = matrix_1_norm[:, i+20]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    sample = torch.tensor(samples[n, :])
                    samples_hv = self.encode(sample) # Encode the inputs
                    self.model_update(samples_hv, label) # Pass input and label to train
                    predictions_testing = self.forward(sample) # Pass samples from test to model (forward function)
                    pred.append(float(predictions_testing[0]))
                    labels_full.append(float(label.unsqueeze(dim=0)))
            print(f"Training root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in sets_testing:
            samples = matrix_1_norm[:, i:i+20]
            labels = matrix_1_norm[:, i+20]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample)
                pred.append(float(predictions[0]))
                labels_full.append(float(label.unsqueeze(dim=0)))

        print(
            f"Testing root mean squared error of testing {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
for i in range(1,50):
    print(i)
    model = MultiModel_With_NonLinear_Sin(2, 20, i) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
for i in range(50, 100, 10):
    print(i)
    model = MultiModel_With_NonLinear_Sin(2, 20, i) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
for i in range(100, 1100, 100):
    print(i)
    model = MultiModel_With_NonLinear_Sin(2, 20, i) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
# Out:
# 1
# Training root mean squared error of 0.202
# Testing root mean squared error of testing 0.346
# 2
# Training root mean squared error of 0.129
# Testing root mean squared error of testing 0.164
# 3
# Training root mean squared error of 0.130
# Testing root mean squared error of testing 0.168
# 4
# Training root mean squared error of 0.121
# Testing root mean squared error of testing 0.170
# 5
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.159
# 6
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.146
# 7
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.152
# 8
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 9
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 10
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.153
# 11
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.153
# 12
# Training root mean squared error of 0.114
# Testing root mean squared error of testing 0.150
# 13
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.154
# 14
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.148
# 15
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 16
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 17
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.153
# 18
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 19
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 20
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 21
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.156
# 22
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 23
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 24
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.155
# 25
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 26
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.153
# 27
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.153
# 28
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 29
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 30
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.154
# 31
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.153
# 32
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.149
# 33
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 34
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.153
# 35
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.148
# 36
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.154
# 37
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.148
# 38
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 39
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 40
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 41
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 42
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 43
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 44
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 45
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 46
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 47
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 48
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 49
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.148
# 50
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.149
# 60
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 70
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 80
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.154
# 90
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.152
# 100
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.153
# 200
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 300
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.149
# 400
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.149
# 500
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 600
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 700
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 800
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.150
# 900
# Training root mean squared error of 0.113
# Testing root mean squared error of testing 0.151
# 1000
# Training root mean squared error of 0.112
# Testing root mean squared error of testing 0.149

# %% [markdown]
# #### Same test but modify r
# r = randomness -> r-value to interpolate between level-hypervectors

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, embeddings, cos_similarity, bind, multiset, hard_quantize

from scipy.special import softmax

import time

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, size, levels, r):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.flatten = torch.nn.Flatten()
        self.position = embeddings.Random(size, d)
        self.value = embeddings.Level(levels, d, randomness=r)
        self.cluster = functional.random_hv(models, d)
        self.size = size
        self.r = r

    def encode(self, x): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        sample_hv = bind(self.position.weight, self.value(x))
        sample_hv = multiset(sample_hv)
        return hard_quantize(sample_hv)

    def model_update(self, x, y): # update # y = no hv
        #x = torch.reshape(x, (1,d))
        confidence = np.transpose(softmax(cos_similarity(x, self.cluster))) # Compare input with cluster
        model_result = F.linear(x, self.M.type(torch.FloatTensor))
        update = self.M + (float(self.lr) * float(y - F.linear(confidence, model_result)) * x) # Model + alpha*(Error)*(x)
        #update = update.mean(0) # Mean by columns
        self.M = update.type(torch.FloatTensor) # New 
        # update cluster center?
        center = [num.item() for num in confidence].index(max(confidence).item())
        self.cluster[center] = self.cluster[center] + (1-max(confidence)) * x
        return center
        

    def forward(self, x):
        enc = torch.reshape(self.encode(x), (1,d))
        confidence = np.transpose(softmax(cos_similarity(self.cluster, enc))) # Compare input with cluster
        model_result = F.linear(enc, self.M).type(torch.FloatTensor)
        res = F.linear(confidence, model_result) # Multiply enc (x) * weights (Model) = Dot product
        return res # Return the resolutions

    def train(self, sets_training, matrix_1_norm, epochs):
        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for i in sets_training:
                samples = matrix_1_norm[:, i:i+self.size]
                labels = matrix_1_norm[:, i+self.size]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    sample = torch.tensor(samples[n, :])
                    samples_hv = self.encode(sample) # Encode the inputs
                    self.model_update(samples_hv, label) # Pass input and label to train
                    predictions_testing = self.forward(sample) # Pass samples from test to model (forward function)
                    pred.append(float(predictions_testing[0]))
                    labels_full.append(float(label.unsqueeze(dim=0)))

            print(f"Training root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in sets_testing:
            samples = matrix_1_norm[:, i:i+self.size]
            labels = matrix_1_norm[:, i+self.size]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample)
                pred.append(float(predictions[0]))
                labels_full.append(float(label.unsqueeze(dim=0)))

        print(
            f"Testing root mean squared error of testing {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
i = 0
while i < 1.1:
    print(i)
    model = MultiModel_With_NonLinear_Sin(size = 20, levels = 6, r = i) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
    i += 0.05
# Out:
# 0
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.143
# 0.05
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.143
# 0.1
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.146
# 0.15000000000000002
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.144
# 0.2
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.143
# 0.25
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.141
# 0.3
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.142
# 0.35
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.143
# 0.39999999999999997
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.140
# 0.44999999999999996
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.140
# 0.49999999999999994
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.137
# 0.5499999999999999
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.137
# 0.6
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.137
# 0.65
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.136
# 0.7000000000000001
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.135
# 0.7500000000000001
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.133
# 0.8000000000000002
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.135
# 0.8500000000000002
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.133
# 0.9000000000000002
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.133
# 0.9500000000000003
# Training root mean squared error of 0.118
# Testing root mean squared error of testing 0.132
# 1.0000000000000002
# Training root mean squared error of 0.121
# Testing root mean squared error of testing 0.128
# 1.0500000000000003
# Training root mean squared error of 0.121
# Testing root mean squared error of testing 0.130

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, embeddings, cos_similarity, bind, multiset, hard_quantize, permute

from scipy.special import softmax

import time

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, size, levels, r):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.position = embeddings.Random(size, d)
        self.value = embeddings.Level(levels, d, randomness=r)
        self.cluster = functional.random_hv(models, d)
        self.size = size
        self.r = r

    def encode(self, x): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        #x = self.flatten(x)
        sample_hv = bind(self.position.weight, self.value(x))
        for i, hv in enumerate(sample_hv):
            sample_hv[i] = permute(hv, shifts=i)
        sample_hv = multiset(sample_hv)
        return hard_quantize(sample_hv)

    def model_update(self, x, y): # update # y = no hv
        #x = torch.reshape(x, (1,d))
        confidence = np.transpose(softmax(cos_similarity(x, self.cluster))) # Compare input with cluster
        model_result = F.linear(x, self.M.type(torch.FloatTensor))
        update = self.M + (float(self.lr) * float(y - F.linear(confidence, model_result)) * x) # Model + alpha*(Error)*(x)
        #update = update.mean(0) # Mean by columns
        self.M = update.type(torch.FloatTensor) # New 
        # update cluster center?
        center = [num.item() for num in confidence].index(max(confidence).item())
        self.cluster[center] = self.cluster[center] + (1-max(confidence)) * x
        return center
        

    def forward(self, x):
        enc = torch.reshape(self.encode(x), (1,d))
        confidence = np.transpose(softmax(cos_similarity(self.cluster, enc))) # Compare input with cluster
        model_result = F.linear(enc, self.M).type(torch.FloatTensor)
        res = F.linear(confidence, model_result) # Multiply enc (x) * weights (Model) = Dot product
        return res # Return the resolutions

    def train(self, sets_training, matrix_1_norm, epochs):
        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for i in sets_training:
                samples = matrix_1_norm[:, i:i+self.size]
                labels = matrix_1_norm[:, i+self.size]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    sample = torch.tensor(samples[n, :])
                    samples_hv = self.encode(sample) # Encode the inputs
                    self.model_update(samples_hv, label) # Pass input and label to train
                    predictions_testing = self.forward(sample) # Pass samples from test to model (forward function)
                    pred.append(float(predictions_testing[0]))
                    labels_full.append(float(label.unsqueeze(dim=0)))
            print(f"Training root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in sets_testing:
            samples = matrix_1_norm[:, i:i+self.size]
            labels = matrix_1_norm[:, i+self.size]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample)
                pred.append(float(predictions[0]))
                labels_full.append(float(label.unsqueeze(dim=0)))

        print(
            f"Testing root mean squared error of testing {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
i = 0
while i < 1.1:
    print(i)
    model = MultiModel_With_NonLinear_Sin(size = 20, levels = 6, r = i) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
    i += 0.05
# Out:
# 0
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.149
# 0.05
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.146
# 0.1
# Training root mean squared error of 0.115
# Testing root mean squared error of testing 0.147
# 0.15000000000000002
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.145
# 0.2
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.150
# 0.25
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.148
# 0.3
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.145
# 0.35
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.146
# 0.39999999999999997
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.144
# 0.44999999999999996
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.143
# 0.49999999999999994
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.141
# 0.5499999999999999
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.139
# 0.6
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.139
# 0.65
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.139
# 0.7000000000000001
# Training root mean squared error of 0.116
# Testing root mean squared error of testing 0.139
# 0.7500000000000001
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.138
# 0.8000000000000002
# Training root mean squared error of 0.117
# Testing root mean squared error of testing 0.136
# 0.8500000000000002
# Training root mean squared error of 0.118
# Testing root mean squared error of testing 0.137
# 0.9000000000000002
# Training root mean squared error of 0.118
# Testing root mean squared error of testing 0.134
# 0.9500000000000003
# Training root mean squared error of 0.119
# Testing root mean squared error of testing 0.133
# 1.0000000000000002
# Training root mean squared error of 0.122
# Testing root mean squared error of testing 0.130
# 1.0500000000000003
# Training root mean squared error of 0.123
# Testing root mean squared error of testing 0.132

# %% [markdown]
# #### Combine this new encoding with spectral clustering

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional
from torchhd import embeddings
from torchhd import cos_similarity

from scipy.special import softmax

import time
from sklearn.cluster import SpectralClustering

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, size, levels, r):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.position = embeddings.Random(size, d)
        self.value = embeddings.Level(levels, d, randomness=r)
        self.cluster = functional.random_hv(models, d)
        self.size = size
        self.r = r
        self.cluster_model = None
        self.training_samples = None

    def encode(self, x): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        sample_hv = bind(self.position.weight, self.value(x))
        sample_hv = multiset(sample_hv)
        return hard_quantize(sample_hv)

    def model_update(self, x, y, cluster): # update # y = no hv
        x = torch.reshape(x, (1,d))
        #confidence = np.transpose(softmax(cos_similarity(self.cluster, x))) # Compare input with cluster
        model_result = F.linear(x.type(torch.FloatTensor), self.M[cluster].type(torch.FloatTensor))
        update = self.M[cluster] + (self.lr * (y - model_result) * x) # Model + alpha*(Error)*(x)
        self.M[cluster] = update[0] # New 
        #center = [num.item() for num in confidence[0]].index(max(confidence[0]).item())
        #self.cluster[center] = self.cluster[center] + (1-max(confidence[0])) * x
        #return center
    
    def forward(self, x):
        enc = torch.reshape(self.encode(x), (1,d))
        #confidence = np.transpose(softmax(cos_similarity(self.cluster, enc))) # Compare input with cluster
        similarity = cos_similarity(self.training_samples, enc)
        #print(similarity.index(max(similarity)))
        i = list(similarity.numpy()).index(max(similarity).numpy()[0])
        #i,j = np.where(similarity.numpy() == max(similarity).numpy())
        model_result = F.linear(enc, self.M[self.cluster_model[i]].type(torch.FloatTensor))
        #res = F.linear(confidence, model_result) # Multiply enc (x) * weights (Model) = Dot product
        return model_result # Return the resolutions
    
    def train(self, sets_training, matrix_1_norm, epochs):
        
        full_samples = {}
        for time, i in enumerate(sets_training):
            samples = matrix_1_norm[:, i:i+self.size]
            for n in range(0, samples.shape[0], 1):
                sample = torch.tensor(samples[n, :])
                full_samples[(samples.shape[0]*time) + n] = sample

        if(self.cluster_model == None):
            encoded = torch.zeros(len(full_samples), 10000)
            for i, samp in (full_samples.items()):
                encoded[i, :] = self.encode(samp)
            self.training_samples = encoded
            affinity_matrix = cos_similarity(encoded, encoded)
            clustering = SpectralClustering(n_clusters=models, assign_labels='discretize', 
                                            random_state=0, affinity='precomputed').fit(affinity_matrix)
            self.cluster_model = clustering.labels_

        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for time, i in enumerate(sets_training):
                #samples = matrix_1_norm[:, i:i+40]
                labels = matrix_1_norm[:, i+self.size]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    item = (samples.shape[0]*time) + n
                    self.model_update(encoded[item], label, self.cluster_model[item]) # Pass input and label to train
                    #predictions_testing = self(full_samples[item]) # Pass samples from test to model (forward function)
                    #pred.append(predictions_testing[0])
                    #labels_full.append(label.unsqueeze(dim=0))

            #print(f"Training root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in sets_testing:
            samples = matrix_1_norm[:, i:i+self.size]
            labels = matrix_1_norm[:, i+self.size]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample)
                pred.append(float(predictions[0]))
                labels_full.append(float(label.unsqueeze(dim=0)))
        print(f"Testing root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
  
model = MultiModel_With_NonLinear_Sin(size = 20, levels = 6, r = 1.0) # 1 class, 5

# %%
model = MultiModel_With_NonLinear_Sin(size = 20, levels = 6, r = 0.25) # 1 class, 5
model.train(sets_training, matrix_1_norm, 1)
model.test(sets_validation, matrix_1_norm)
# Out:
# Testing root mean squared error of 0.139

# %%
model.test(sets_testing, matrix_1_norm)
# Out:
# Testing root mean squared error of 0.131

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, embeddings, cos_similarity, bind, multiset, hard_quantize, permute

from scipy.special import softmax

import time
from sklearn.cluster import SpectralClustering

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, size, levels, r):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.position = embeddings.Random(size, d)
        self.value = embeddings.Level(levels, d, randomness=r)
        self.cluster = functional.random_hv(models, d)
        self.size = size
        self.r = r
        self.cluster_model = None
        self.training_samples = None

    def encode(self, x): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        #x = self.flatten(x)
        sample_hv = bind(self.position.weight, self.value(x))
        for i, hv in enumerate(sample_hv):
            sample_hv[i] = permute(hv, shifts=i)
        sample_hv = multiset(sample_hv)
        return hard_quantize(sample_hv)

    def model_update(self, x, y, cluster): # update # y = no hv
        x = torch.reshape(x, (1,d))
        #confidence = np.transpose(softmax(cos_similarity(self.cluster, x))) # Compare input with cluster
        model_result = F.linear(x.type(torch.FloatTensor), self.M[cluster].type(torch.FloatTensor))
        update = self.M[cluster] + (self.lr * (y - model_result) * x) # Model + alpha*(Error)*(x)
        self.M[cluster] = update[0] # New 
        #center = [num.item() for num in confidence[0]].index(max(confidence[0]).item())
        #self.cluster[center] = self.cluster[center] + (1-max(confidence[0])) * x
        #return center
    
    def forward(self, x):
        enc = torch.reshape(self.encode(x), (1,d))
        #confidence = np.transpose(softmax(cos_similarity(self.cluster, enc))) # Compare input with cluster
        similarity = cos_similarity(self.training_samples, enc)
        #print(similarity.index(max(similarity)))
        i = list(similarity.numpy()).index(max(similarity).numpy()[0])
        #i,j = np.where(similarity.numpy() == max(similarity).numpy())
        model_result = F.linear(enc, self.M[self.cluster_model[i]].type(torch.FloatTensor))
        #res = F.linear(confidence, model_result) # Multiply enc (x) * weights (Model) = Dot product
        return model_result # Return the resolutions
    
    def train(self, sets_training, matrix_1_norm, epochs):
        
        full_samples = {}
        for time, i in enumerate(sets_training):
            samples = matrix_1_norm[:, i:i+self.size]
            for n in range(0, samples.shape[0], 1):
                sample = torch.tensor(samples[n, :])
                full_samples[(samples.shape[0]*time) + n] = sample

        if(self.cluster_model == None):
            encoded = torch.zeros(len(full_samples), 10000)
            for i, samp in (full_samples.items()):
                encoded[i, :] = self.encode(samp)
            self.training_samples = encoded
            affinity_matrix = cos_similarity(encoded, encoded)
            clustering = SpectralClustering(n_clusters=models, assign_labels='discretize', 
                                            random_state=0, affinity='precomputed').fit(affinity_matrix)
            self.cluster_model = clustering.labels_

        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for time, i in enumerate(sets_training):
                #samples = matrix_1_norm[:, i:i+40]
                labels = matrix_1_norm[:, i+self.size]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    item = (samples.shape[0]*time) + n
                    self.model_update(encoded[item], label, self.cluster_model[item]) # Pass input and label to train
                    #predictions_testing = self(full_samples[item]) # Pass samples from test to model (forward function)
                    #pred.append(predictions_testing[0])
                    #labels_full.append(label.unsqueeze(dim=0))

            #print(f"Training root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in sets_testing:
            samples = matrix_1_norm[:, i:i+self.size]
            labels = matrix_1_norm[:, i+self.size]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample)
                pred.append(float(predictions[0]))
                labels_full.append(float(label.unsqueeze(dim=0)))
        print(f"Testing root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
  
#model = MultiModel_With_NonLinear_Sin(size = 20, levels = 6, r = 1.0) # 1 class, 5

# %%
model = MultiModel_With_NonLinear_Sin(size = 20, levels = 6, r = 0.25) # 1 class, 5
model.train(sets_training, matrix_1_norm, 1)
model.test(sets_validation, matrix_1_norm)
# Out:
# Testing root mean squared error of 0.141

# %%
model = MultiModel_With_NonLinear_Sin(size = 20, levels = 100, r = 0.25) # 1 class, 5
model.train(sets_training, matrix_1_norm, 1)
model.test(sets_validation, matrix_1_norm)
# Out:
# Testing root mean squared error of 0.133

# %%
levels = [1,5,10,20,50,100,200,500,1000]
r = [0, 0.05, 0.1, 0.25, 0.5, 1]
levels_r = []
for l in levels:
    for r_i in r:
        levels_r.append((l,r_i))

for level, r in levels_r:
    model = MultiModel_With_NonLinear_Sin(size = 20, levels = level, r = r) # 1 class, 5
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_validation, matrix_1_norm)
# Out:
# Testing root mean squared error of 0.332
# Testing root mean squared error of 0.332
# Testing root mean squared error of 0.332
# Testing root mean squared error of 0.332
# Testing root mean squared error of 0.332
# Testing root mean squared error of 0.332
# Testing root mean squared error of 0.141
# Testing root mean squared error of 0.145
# Testing root mean squared error of 0.140
# Testing root mean squared error of 0.144
# Testing root mean squared error of 0.143
# Testing root mean squared error of 0.141
# Testing root mean squared error of 0.142
# Testing root mean squared error of 0.140
# Testing root mean squared error of 0.134
# Testing root mean squared error of 0.135
# Testing root mean squared error of 0.142
# Testing root mean squared error of 0.139
# Testing root mean squared error of 0.134
# Testing root mean squared error of 0.131
# Testing root mean squared error of 0.131
# Testing root mean squared error of 0.138
# Testing root mean squared error of 0.140
# Testing root mean squared error of 0.144
# Testing root mean squared error of 0.136
# Testing root mean squared error of 0.134
# Testing root mean squared error of 0.134
# Testing root mean squared error of 0.138
# Testing root mean squared error of 0.140
# Testing root mean squared error of 0.168
# Testing root mean squared error of 0.135
# Testing root mean squared error of 0.138
# Testing root mean squared error of 0.136
# Testing root mean squared error of 0.132
# Testing root mean squared error of 0.134
# Testing root mean squared error of 0.177
# Testing root mean squared error of 0.138
# Testing root mean squared error of 0.131
# Testing root mean squared error of 0.135
# Testing root mean squared error of 0.130
# Testing root mean squared error of 0.139
# Testing root mean squared error of 0.188
# Testing root mean squared error of 0.137
# Testing root mean squared error of 0.131
# Testing root mean squared error of 0.131
# Testing root mean squared error of 0.131
# Testing root mean squared error of 0.135
# Testing root mean squared error of 0.221
# Testing root mean squared error of 0.137
# Testing root mean squared error of 0.129
# Testing root mean squared error of 0.135
# Testing root mean squared error of 0.135
# Testing root mean squared error of 0.139
# Testing root mean squared error of 0.240

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, embeddings, cos_similarity, bind, multiset, hard_quantize, permute

from scipy.special import softmax

import time
from sklearn.cluster import SpectralClustering

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, size, levels, r):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.position = embeddings.Random(size, d)
        self.value = embeddings.Level(levels, d, randomness=r)
        self.cluster = functional.random_hv(models, d)
        self.size = size
        self.r = r
        self.cluster_model = None
        self.training_samples = None

    def encode(self, x): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        #x = self.flatten(x)
        sample_hv = self.value(x)
        for i, hv in enumerate(sample_hv):
            sample_hv[i] = permute(hv, shifts=i)
        sample_hv = multiset(sample_hv)
        return hard_quantize(sample_hv)

    def model_update(self, x, y, cluster): # update # y = no hv
        x = torch.reshape(x, (1,d))
        #confidence = np.transpose(softmax(cos_similarity(self.cluster, x))) # Compare input with cluster
        model_result = F.linear(x.type(torch.FloatTensor), self.M[cluster].type(torch.FloatTensor))
        update = self.M[cluster] + (self.lr * (y - model_result) * x) # Model + alpha*(Error)*(x)
        self.M[cluster] = update[0] # New 
        #center = [num.item() for num in confidence[0]].index(max(confidence[0]).item())
        #self.cluster[center] = self.cluster[center] + (1-max(confidence[0])) * x
        #return center
    
    def forward(self, x):
        enc = torch.reshape(self.encode(x), (1,d))
        #confidence = np.transpose(softmax(cos_similarity(self.cluster, enc))) # Compare input with cluster
        similarity = cos_similarity(self.training_samples, enc)
        #print(similarity.index(max(similarity)))
        i = list(similarity.numpy()).index(max(similarity).numpy()[0])
        #i,j = np.where(similarity.numpy() == max(similarity).numpy())
        model_result = F.linear(enc, self.M[self.cluster_model[i]].type(torch.FloatTensor))
        #res = F.linear(confidence, model_result) # Multiply enc (x) * weights (Model) = Dot product
        return model_result # Return the resolutions
    
    def train(self, sets_training, matrix_1_norm, epochs):
        
        full_samples = {}
        for time, i in enumerate(sets_training):
            samples = matrix_1_norm[:, i:i+self.size]
            for n in range(0, samples.shape[0], 1):
                sample = torch.tensor(samples[n, :])
                full_samples[(samples.shape[0]*time) + n] = sample

        if(self.cluster_model == None):
            encoded = torch.zeros(len(full_samples), 10000)
            for i, samp in (full_samples.items()):
                encoded[i, :] = self.encode(samp)
            self.training_samples = encoded
            affinity_matrix = cos_similarity(encoded, encoded)
            clustering = SpectralClustering(n_clusters=models, assign_labels='discretize', 
                                            random_state=0, affinity='precomputed').fit(affinity_matrix)
            self.cluster_model = clustering.labels_

        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for time, i in enumerate(sets_training):
                #samples = matrix_1_norm[:, i:i+40]
                labels = matrix_1_norm[:, i+self.size]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    item = (samples.shape[0]*time) + n
                    self.model_update(encoded[item], label, self.cluster_model[item]) # Pass input and label to train
                    #predictions_testing = self(full_samples[item]) # Pass samples from test to model (forward function)
                    #pred.append(predictions_testing[0])
                    #labels_full.append(label.unsqueeze(dim=0))

            #print(f"Training root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in sets_testing:
            samples = matrix_1_norm[:, i:i+self.size]
            labels = matrix_1_norm[:, i+self.size]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample)
                pred.append(float(predictions[0]))
                labels_full.append(float(label.unsqueeze(dim=0)))
        print(f"Testing root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")
  
#model = MultiModel_With_NonLinear_Sin(size = 20, levels = 6, r = 1.0) # 1 class, 5

# %%
model = MultiModel_With_NonLinear_Sin(size = 20, levels = 200, r = 0.25) # 1 class, 5
model.train(sets_training, matrix_1_norm, 1)
model.test(sets_validation, matrix_1_norm)
# Out:
# Testing root mean squared error of 0.133

# %% [markdown]
# #### Bundle with season - Linear

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, bind
from torchhd import embeddings
from torchhd import cos_similarity

from scipy.special import softmax

import time
from sklearn.cluster import SpectralClustering

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, num_classes, size):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.project = embeddings.Projection(size, d).double() # 5 features, 10000 dimensions = hypervectors like weights?
        self.project.weight.data.normal_(0, 1) # Normal distributions mean=0.0, std=1.0
        self.bias = nn.parameter.Parameter(torch.empty(d), requires_grad=False)
        self.bias.data.uniform_(0, 2 * math.pi) # bias
        self.cluster_model = None
        self.training_samples = None
        self.time_stamp = functional.level_hv(4, d)

    def encode(self, x, time): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        enc = self.project(x)
        sample_hv = torch.cos(enc + self.bias) * torch.sin(enc) 
        season = ( time // 13 ) % 4
        return bind(functional.hard_quantize(sample_hv), self.time_stamp[season])

    def model_update(self, x, y, cluster): # update # y = no hv
        x = torch.reshape(x, (1,d))
        model_result = F.linear(x.type(torch.FloatTensor), self.M[cluster].type(torch.FloatTensor))
        update = self.M[cluster] + (self.lr * (y - model_result) * x) # Model + alpha*(Error)*(x)
        self.M[cluster] = update[0] # New 
    
    def forward(self, x, time):
        enc = torch.reshape(self.encode(x, time), (1,d))
        similarity = cos_similarity(self.training_samples, enc)
        i = list(similarity.numpy()).index(max(similarity).numpy()[0])
        model_result = F.linear(enc, self.M[self.cluster_model.labels_[i]])
        return model_result # Return the resolutions
    
    def train(self, sets_training, matrix_1_norm, epochs):
        
        full_samples = {}
        for time, i in enumerate(sets_training):
            samples = matrix_1_norm[:, i:i+20]
            for n in range(0, samples.shape[0], 1):
                sample = torch.tensor(samples[n, :])
                full_samples[(samples.shape[0]*time) + n] = (sample, i)

        if(self.cluster_model == None):
            encoded = torch.zeros(len(full_samples), 10000)
            for i, samp in (full_samples.items()):
                encoded[i, :] = self.encode(samp[0], samp[1])
                print(encoded[i, :])
            self.training_samples = encoded
            affinity_matrix = cos_similarity(encoded, encoded)
            print("Checking")
            for i in range(affinity_matrix.shape[0]):
                line = affinity_matrix[i].numpy()
                for j in range(affinity_matrix.shape[1]):
                    if np.isnan(line[j]) or math. isinf(line[j]):
                        print(i,j)
            print("Done checking")
            clustering = SpectralClustering(n_clusters=models, assign_labels='discretize', 
                                            random_state=0, affinity='precomputed').fit(affinity_matrix.numpy())
            self.cluster_model = clustering

        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for time, i in enumerate(sets_training):
                labels = matrix_1_norm[:, i+20]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    item = (samples.shape[0]*time) + n
                    self.model_update(encoded[item], label, self.cluster_model.labels_[item]) 
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in tqdm(sets_testing):
            samples = matrix_1_norm[:, i:i+20]
            labels = matrix_1_norm[:, i+20]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample, i)
                pred.append(predictions[0])
                labels_full.append(label.unsqueeze(dim=0))
        print(f"Testing root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
model = MultiModel_With_NonLinear_Sin(2, 20)
for i in range(1,3):
    print(i)
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_testing, matrix_1_norm)
# Out:
# 1
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([-1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([-1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([-1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([-1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([-1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([-1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([-1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([-1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([-1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([-1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([-1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([-1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([-1.,  1.,  1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([-1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([-1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([-1.,  1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([-1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([-1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([-1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([-1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([-1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# ...
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([-1.,  1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([-1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([-1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([-1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1.,  1.])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1.,  1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([-1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([-1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1., -1., -1.])
# tensor([ 1., -1.,  1.,  ..., -1., -1.,  1.])
# tensor([ 1.,  1.,  1.,  ..., -1., -1.,  1.])
# tensor([-1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1.,  1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ..., -1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1., -1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1., -1.,  ...,  1.,  1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1., -1.,  ..., -1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# tensor([ 1., -1.,  1.,  ...,  1., -1.,  1.])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> for i in range(1,3):
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     print(i)
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     model.train(sets_training, matrix_1_norm, 1)
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     model.test(sets_testing, matrix_1_norm)
#
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 6 in MultiModel_With_NonLinear_Sin.train(self, sets_training, matrix_1_norm, epochs)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=71'>72</a>     print(encoded[i, :])
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=72'>73</a> self.training_samples = encoded
# ---> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=73'>74</a> affinity_matrix = cos_similarity(encoded, encoded)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=74'>75</a> print("Checking")
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#W4sZmlsZQ%3D%3D?line=75'>76</a> for i in range(affinity_matrix.shape[0]):
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torchhd\functional.py:751, in cos_similarity(input, others)
#     749 input = as_vsa_model(input)
#     750 others = as_vsa_model(others)
# --> 751 return input.cos_similarity(others)
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torchhd\map.py:319, in MAP.cos_similarity(self, others, eps)
#     316     magnitude = self_mag * others_mag
#     318 magnitude = magnitude.clamp(min=eps)
# --> 319 return F.linear(self.to(dtype), others.to(dtype)) / magnitude
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torch\_tensor.py:1121, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1118     return NotImplemented
#    1120 with _C.DisableTorchFunction():
# -> 1121     ret = func(*args, **kwargs)
#    1122     if func in get_default_nowrap_functions():
#    1123         return ret
#
# RuntimeError: [enforce fail at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10\core\impl\alloc_cpu.cpp:81] data. DefaultCPUAllocator: not enough memory: you tried to allocate 427993344 bytes.

# %% [markdown]
# #### Bundle with season - Circular

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, bind
from torchhd import embeddings
from torchhd import cos_similarity

from scipy.special import softmax

import time
from sklearn.cluster import SpectralClustering

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, num_classes, size):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.project = embeddings.Projection(size, d).double() # 5 features, 10000 dimensions = hypervectors like weights?
        self.project.weight.data.normal_(0, 1) # Normal distributions mean=0.0, std=1.0
        self.bias = nn.parameter.Parameter(torch.empty(d), requires_grad=False)
        self.bias.data.uniform_(0, 2 * math.pi) # bias
        self.cluster_model = None
        self.training_samples = None
        self.time_stamp = functional.circular_hv(4, d)

    def encode(self, x, time): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        enc = self.project(x)
        sample_hv = torch.cos(enc + self.bias) * torch.sin(enc) 
        season = ( time // 13 ) % 4
        return bind(functional.hard_quantize(sample_hv), self.time_stamp[season])

    def model_update(self, x, y, cluster): # update # y = no hv
        x = torch.reshape(x, (1,d))
        model_result = F.linear(x.type(torch.FloatTensor), self.M[cluster].type(torch.FloatTensor))
        update = self.M[cluster] + (self.lr * (y - model_result) * x) # Model + alpha*(Error)*(x)
        self.M[cluster] = update[0] # New 
    
    def forward(self, x, time):
        enc = torch.reshape(self.encode(x, time), (1,d))
        similarity = cos_similarity(self.training_samples, enc)
        i = list(similarity.numpy()).index(max(similarity).numpy()[0])
        model_result = F.linear(enc, self.M[self.cluster_model.labels_[i]])
        return model_result # Return the resolutions
    
    def train(self, sets_training, matrix_1_norm, epochs):
        
        full_samples = {}
        for time, i in enumerate(sets_training):
            samples = matrix_1_norm[:, i:i+20]
            for n in range(0, samples.shape[0], 1):
                sample = torch.tensor(samples[n, :])
                full_samples[(samples.shape[0]*time) + n] = (sample, i)

        if(self.cluster_model == None):
            encoded = torch.zeros(len(full_samples), 10000)
            for i, samp in (full_samples.items()):
                encoded[i, :] = self.encode(samp[0], samp[1])
            self.training_samples = encoded
            affinity_matrix = cos_similarity(encoded, encoded)
            clustering = SpectralClustering(n_clusters=models, assign_labels='discretize', 
                                            random_state=0, affinity='precomputed').fit(affinity_matrix)
            self.cluster_model = clustering

        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for time, i in enumerate(sets_training):
                #samples = matrix_1_norm[:, i:i+40]
                labels = matrix_1_norm[:, i+20]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    item = (samples.shape[0]*time) + n
                    self.model_update(self.training_samples[item], label, self.cluster_model.labels_[item]) 
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in tqdm(sets_testing):
            samples = matrix_1_norm[:, i:i+20]
            labels = matrix_1_norm[:, i+20]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample, i)
                pred.append(predictions[0])
                labels_full.append(label.unsqueeze(dim=0))
        print(f"Testing root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
model = MultiModel_With_NonLinear_Sin(2, 20)
for i in range(1,3):
    print(i)
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_testing, matrix_1_norm)
# Out:
# 1
# 100%|██████████| 3/3 [17:19<00:00, 346.54s/it]
# d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\utils\validation.py:746: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   array = np.asarray(array, order=order, dtype=dtype)
# d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\utils\validation.py:746: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   array = np.asarray(array, order=order, dtype=dtype)
# d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\metrics\_regression.py:95: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# Testing root mean squared error of 0.162
# 2
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> for i in range(1,3):
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     print(i)
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     model.train(sets_training, matrix_1_norm, 1)
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     model.test(sets_testing, matrix_1_norm)
#
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 9 in MultiModel_With_NonLinear_Sin.train(self, sets_training, matrix_1_norm, epochs)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X10sZmlsZQ%3D%3D?line=85'>86</a> label = torch.tensor(labels[n])
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X10sZmlsZQ%3D%3D?line=86'>87</a> item = (samples.shape[0]*time) + n
# ---> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X10sZmlsZQ%3D%3D?line=87'>88</a> self.model_update(encoded[item], label, self.cluster_model.labels_[item])
#
# UnboundLocalError: local variable 'encoded' referenced before assignment

# %% [markdown]
# #### Bundle with Circular Hv seasons

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, bundle
from torchhd import embeddings
from torchhd import cos_similarity

from scipy.special import softmax

import time
from sklearn.cluster import SpectralClustering

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, num_classes, size):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.project = embeddings.Projection(size, d).double() # 5 features, 10000 dimensions = hypervectors like weights?
        self.project.weight.data.normal_(0, 1) # Normal distributions mean=0.0, std=1.0
        self.bias = nn.parameter.Parameter(torch.empty(d), requires_grad=False)
        self.bias.data.uniform_(0, 2 * math.pi) # bias
        self.cluster_model = None
        self.training_samples = None
        self.time_stamp = functional.circular_hv(4, d)

    def encode(self, x, time): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        enc = self.project(x)
        sample_hv = torch.cos(enc + self.bias) * torch.sin(enc) 
        season = ( time // 13 ) % 4
        return bundle(functional.hard_quantize(sample_hv), self.time_stamp[season])

    def model_update(self, x, y, cluster): # update # y = no hv
        x = torch.reshape(x, (1,d))
        model_result = F.linear(x.type(torch.FloatTensor), self.M[cluster].type(torch.FloatTensor))
        update = self.M[cluster] + (self.lr * (y - model_result) * x) # Model + alpha*(Error)*(x)
        self.M[cluster] = update[0] # New 
    
    def forward(self, x, time):
        enc = torch.reshape(self.encode(x, time), (1,d))
        similarity = cos_similarity(self.training_samples, enc)
        i = list(similarity.numpy()).index(max(similarity).numpy()[0])
        model_result = F.linear(enc, self.M[self.cluster_model.labels_[i]])
        return model_result # Return the resolutions
    
    def train(self, sets_training, matrix_1_norm, epochs):
        
        full_samples = {}
        for time, i in enumerate(sets_training):
            samples = matrix_1_norm[:, i:i+20]
            for n in range(0, samples.shape[0], 1):
                sample = torch.tensor(samples[n, :])
                full_samples[(samples.shape[0]*time) + n] = (sample, i)

        if(self.cluster_model == None):
            encoded = torch.zeros(len(full_samples), 10000)
            for i, samp in (full_samples.items()):
                encoded[i, :] = self.encode(samp[0], samp[1])
            self.training_samples = encoded
            affinity_matrix = cos_similarity(encoded, encoded)
            clustering = SpectralClustering(n_clusters=models, assign_labels='discretize', 
                                            random_state=0, affinity='precomputed').fit(affinity_matrix)
            self.cluster_model = clustering

        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for time, i in enumerate(sets_training):
                #samples = matrix_1_norm[:, i:i+40]
                labels = matrix_1_norm[:, i+20]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    item = (samples.shape[0]*time) + n
                    self.model_update(self.training_samples[item], label, self.cluster_model.labels_[item]) 
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in tqdm(sets_testing):
            samples = matrix_1_norm[:, i:i+20]
            labels = matrix_1_norm[:, i+20]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample, i)
                pred.append(predictions[0])
                labels_full.append(label.unsqueeze(dim=0))
        print(f"Testing root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
model = MultiModel_With_NonLinear_Sin(2, 20)
for i in range(1,3):
    print(i)
    model.train(sets_training, matrix_1_norm, 1)
    model.test(sets_testing, matrix_1_norm)
# Out:
# 1
# 100%|██████████| 3/3 [18:18<00:00, 366.15s/it]
# d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\utils\validation.py:746: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   array = np.asarray(array, order=order, dtype=dtype)
# d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\utils\validation.py:746: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   array = np.asarray(array, order=order, dtype=dtype)
# d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\metrics\_regression.py:95: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# Testing root mean squared error of 0.200
# 2
#   0%|          | 0/3 [01:41<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> print(i)
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> model.train(sets_training, matrix_1_norm, 1)
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> model.test(sets_testing, matrix_1_norm)
#
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 12 in MultiModel_With_NonLinear_Sin.test(self, sets_testing, matrix_1_norm)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=97'>98</a> sample = torch.tensor(samples[n, :])
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=98'>99</a> # Pass samples from test to model (forward function)
# --> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=99'>100</a> predictions = self.forward(sample, i)
#     <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=100'>101</a> pred.append(predictions[0])
#     <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=101'>102</a> labels_full.append(label.unsqueeze(dim=0))
#
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 12 in MultiModel_With_NonLinear_Sin.forward(self, x, time)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=51'>52</a> def forward(self, x, time):
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=52'>53</a>     enc = torch.reshape(self.encode(x, time), (1,d))
# ---> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=53'>54</a>     similarity = cos_similarity(self.training_samples, enc)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=54'>55</a>     i = list(similarity.numpy()).index(max(similarity).numpy()[0])
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X12sZmlsZQ%3D%3D?line=55'>56</a>     model_result = F.linear(enc, self.M[self.cluster_model.labels_[i]])
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torchhd\functional.py:751, in cos_similarity(input, others)
#     749 input = as_vsa_model(input)
#     750 others = as_vsa_model(others)
# --> 751 return input.cos_similarity(others)
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torchhd\map.py:319, in MAP.cos_similarity(self, others, eps)
#     316     magnitude = self_mag * others_mag
#     318 magnitude = magnitude.clamp(min=eps)
# --> 319 return F.linear(self.to(dtype), others.to(dtype)) / magnitude
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torch\_tensor.py:1121, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1118     return NotImplemented
#    1120 with _C.DisableTorchFunction():
# -> 1121     ret = func(*args, **kwargs)
#    1122     if func in get_default_nowrap_functions():
#    1123         return ret
#
# KeyboardInterrupt:

# %% [markdown]
# #### MORE SEASONS

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional, bind
from torchhd import embeddings
from torchhd import cos_similarity

from scipy.special import softmax

import time
from sklearn.cluster import SpectralClustering

d = 10000
models = 4

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, num_classes, size):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.project = embeddings.Projection(size, d).double() # 5 features, 10000 dimensions = hypervectors like weights?
        self.project.weight.data.normal_(0, 1) # Normal distributions mean=0.0, std=1.0
        self.bias = nn.parameter.Parameter(torch.empty(d), requires_grad=False)
        self.bias.data.uniform_(0, 2 * math.pi) # bias
        self.cluster_model = None
        self.training_samples = None
        self.time_stamp = functional.circular_hv(8, d)

    def encode(self, x, time): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        enc = self.project(x)
        sample_hv = torch.cos(enc + self.bias) * torch.sin(enc) 
        season = ( time // 13 ) % 8
        return bind(functional.hard_quantize(sample_hv), self.time_stamp[season])

    def model_update(self, x, y, cluster): # update # y = no hv
        x = torch.reshape(x, (1,d))
        model_result = F.linear(x.type(torch.FloatTensor), self.M[cluster].type(torch.FloatTensor))
        update = self.M[cluster] + (self.lr * (y - model_result) * x) # Model + alpha*(Error)*(x)
        self.M[cluster] = update[0] # New 
    
    def forward(self, x, time):
        enc = torch.reshape(self.encode(x, time), (1,d))
        similarity = cos_similarity(self.training_samples, enc)
        i = list(similarity.numpy()).index(max(similarity).numpy()[0])
        model_result = F.linear(enc, self.M[self.cluster_model.labels_[i]])
        return model_result # Return the resolutions
    
    def train(self, sets_training, matrix_1_norm, epochs):
        
        full_samples = {}
        for time, i in enumerate(sets_training):
            samples = matrix_1_norm[:, i:i+20]
            for n in range(0, samples.shape[0], 1):
                sample = torch.tensor(samples[n, :])
                full_samples[(samples.shape[0]*time) + n] = (sample, i)

        if(self.cluster_model == None):
            encoded = torch.zeros(len(full_samples), 10000)
            for i, samp in (full_samples.items()):
                encoded[i, :] = self.encode(samp[0], samp[1])
            self.training_samples = encoded
            affinity_matrix = cos_similarity(encoded, encoded)
            clustering = SpectralClustering(n_clusters=models, assign_labels='discretize', 
                                            random_state=0, affinity='precomputed').fit(affinity_matrix)
            self.cluster_model = clustering

        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for time, i in enumerate(sets_training):
                #samples = matrix_1_norm[:, i:i+40]
                labels = matrix_1_norm[:, i+20]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    item = (samples.shape[0]*time) + n
                    self.model_update(self.training_samples[item], label, self.cluster_model.labels_[item]) 
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in tqdm(sets_testing):
            samples = matrix_1_norm[:, i:i+20]
            labels = matrix_1_norm[:, i+20]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample, i)
                pred.append(predictions[0])
                labels_full.append(label.unsqueeze(dim=0))
        print(f"Testing root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
model = MultiModel_With_NonLinear_Sin(2, 20)
model.train(sets_training, matrix_1_norm, 1)
model.test(sets_testing, matrix_1_norm)
# Out:
# d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\scipy\sparse\csgraph\_laplacian.py:118: RuntimeWarning: invalid value encountered in sqrt
#   w = np.where(isolated_node_mask, 1, np.sqrt(w))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> model = MultiModel_With_NonLinear_Sin(2, 20)
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> model.train(sets_training, matrix_1_norm, 1)
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> model.test(sets_testing, matrix_1_norm)
#
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 15 in MultiModel_With_NonLinear_Sin.train(self, sets_training, matrix_1_norm, epochs)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=71'>72</a>     self.training_samples = encoded
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=72'>73</a>     affinity_matrix = cos_similarity(encoded, encoded)
# ---> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=73'>74</a>     clustering = SpectralClustering(n_clusters=models, assign_labels='discretize',
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=74'>75</a>                                     random_state=0, affinity='precomputed').fit(affinity_matrix)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=75'>76</a>     self.cluster_model = clustering
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X21sZmlsZQ%3D%3D?line=77'>78</a> for _ in range(epochs): # Number of iterations for all the samples
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\cluster\_spectral.py:622, in SpectralClustering.fit(self, X, y)
#     617     self.affinity_matrix_ = pairwise_kernels(
#     618         X, metric=self.affinity, filter_params=True, **params
#     619     )
#     621 random_state = check_random_state(self.random_state)
# --> 622 self.labels_ = spectral_clustering(
#     623     self.affinity_matrix_,
#     624     n_clusters=self.n_clusters,
#     625     n_components=self.n_components,
#     626     eigen_solver=self.eigen_solver,
#     627     random_state=random_state,
#     628     n_init=self.n_init,
#     629     eigen_tol=self.eigen_tol,
#     630     assign_labels=self.assign_labels,
#     631     verbose=self.verbose,
#     632 )
#     633 return self
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\cluster\_spectral.py:300, in spectral_clustering(affinity, n_clusters, n_components, eigen_solver, random_state, n_init, eigen_tol, assign_labels, verbose)
#     292 n_components = n_clusters if n_components is None else n_components
#     294 # We now obtain the real valued solution matrix to the
#     295 # relaxed Ncut problem, solving the eigenvalue problem
#     296 # L_sym x = lambda x  and recovering u = D^-1/2 x.
#     297 # The first eigenvector is constant only for fully connected graphs
#     298 # and should be kept for spectral clustering (drop_first = False)
#     299 # See spectral_embedding documentation.
# --> 300 maps = spectral_embedding(
#     301     affinity,
#     302     n_components=n_components,
#     303     eigen_solver=eigen_solver,
#     304     random_state=random_state,
#     305     eigen_tol=eigen_tol,
#     306     drop_first=False,
#     307 )
#     308 if verbose:
#     309     print(f"Computing label assignment using {assign_labels}")
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\sklearn\manifold\_spectral_embedding.py:299, in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first)
#     297 laplacian *= -1
#     298 v0 = _init_arpack_v0(laplacian.shape[0], random_state)
# --> 299 _, diffusion_map = eigsh(
#     300     laplacian, k=n_components, sigma=1.0, which="LM", tol=eigen_tol, v0=v0
#     301 )
#     302 embedding = diffusion_map.T[n_components::-1]
#     303 if norm_laplacian:
#     304     # recover u = D^-1/2 x from the eigenvector output x
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py:1644, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1642 matvec = None
#    1643 if OPinv is None:
# -> 1644     Minv_matvec = get_OPinv_matvec(A, M, sigma,
#    1645                                    hermitian=True, tol=tol)
#    1646 else:
#    1647     OPinv = _aslinearoperator_with_dtype(OPinv)
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py:1069, in get_OPinv_matvec(A, M, sigma, hermitian, tol)
#    1067         A = A + 0j
#    1068     A.flat[::A.shape[1] + 1] -= sigma
# -> 1069     return LuInv(A).matvec
#    1070 elif isspmatrix(A) or is_pydata_spmatrix(A):
#    1071     A = A - sigma * eye(A.shape[0])
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py:936, in LuInv.__init__(self, M)
#     935 def __init__(self, M):
# --> 936     self.M_lu = lu_factor(M)
#     937     self.shape = M.shape
#     938     self.dtype = M.dtype
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\scipy\linalg\decomp_lu.py:70, in lu_factor(a, overwrite_a, check_finite)
#      16 """
#      17 Compute pivoted LU decomposition of a matrix.
#      18
#    (...)
#      67 True
#      68 """
#      69 if check_finite:
# ---> 70     a1 = asarray_chkfinite(a)
#      71 else:
#      72     a1 = asarray(a)
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\numpy\lib\function_base.py:603, in asarray_chkfinite(a, dtype, order)
#     601 a = asarray(a, dtype=dtype, order=order)
#     602 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 603     raise ValueError(
#     604         "array must not contain infs or NaNs")
#     605 return a
#
# ValueError: array must not contain infs or NaNs

# %% [markdown]
# #### Tryit with London Smartmeters becauuuuse -> Time series are longer -> Better temporal encoding

# %% [markdown]
# ##### Normal Spectral Clustering RegHD

# %%
parent = 'multipletimeseriesforecasting/preprocessed-data/'

path = os.path.join(parent, 'LondonSmartMeters/London_elec_HalfHourly.csv')

dl = DatasetLoader('LondonSmartMeters', path)

matrix_1_original = dl.dataset_load_and_preprocess("original")
matrix_1_norm = dl.dataset_load_and_preprocess("normalized")
print(matrix_1_norm.shape)
# Out:
# ---------------------------------------------------
# Dataset name:  LondonSmartMeters
# Dataset contains missing values?  False
# --------------------------
# ---------------------------------------------------
# Dataset name:  LondonSmartMeters
# Dataset contains missing values?  False
# --------------------------
# (504, 9983)

# %%
sample_len = int(matrix_1_norm.shape[1]*(0.01))
print("Sample_len total", sample_len)

np.random.seed(1)
sets = np.random.choice(matrix_1_norm.shape[1]-40, int(sample_len), replace=False)
sets_training, sets_testing = sets[:int(len(sets)*.8)], sets[int(len(sets)*.8):]
print(sets_training, sets_testing)
# Out:
# Sample_len total 99
# [7809 1518  895  274 3329 2245 9733 2680 8824 7093  372 1433 6801 4114
#  9236 2932 4638 3983 7234  825 5343 2385 5821 8316 7868 6568 2597 2844
#  2373 1797 4631 9591 3085 8557 2575 7876 2122 9180 2940 6720 4997 1731
#  5387  574 2311  278 2167  260 5471 9200 4171  804 4036 9427 7394 4511
#  6375 6748 1967 6327 8052 6229 9620  793 5260 5142 3382 2354 4506 8244
#  5569 7793 1163 9197 5358 8850  222 9204  218] [8975 3709 6304  763 8232 1510 8759 9882 2625 5220 4076 4033  408 7624
#  6157 5696 6790 9280 3019 7779]

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data

# Note: this example requires the torchmetrics library: https://torchmetrics.readthedocs.io
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

from torchhd import functional
from torchhd import embeddings
from torchhd import cos_similarity

from scipy.special import softmax

import time
from sklearn.cluster import SpectralClustering

d = 10000
models = 32

# Model based on RegHD application for Single model regression -> No comparing which cluster
class MultiModel_With_NonLinear_Sin(nn.Module):
    def __init__(self, num_classes, size):
        super(MultiModel_With_NonLinear_Sin, self).__init__()

        self.lr = 0.00001 # alpha
        self.M = torch.zeros(models, d).double() # Model initializes in 0
        self.project = embeddings.Projection(size, d).double() # 5 features, 10000 dimensions = hypervectors like weights?
        self.project.weight.data.normal_(0, 1) # Normal distributions mean=0.0, std=1.0
        self.bias = nn.parameter.Parameter(torch.empty(d), requires_grad=False)
        self.bias.data.uniform_(0, 2 * math.pi) # bias
        self.cluster_model = None
        self.training_samples = None

    def encode(self, x): # encoding a value
        for i in range(len(x)):
            x[i] = float(x[i])
        enc = self.project(x)
        sample_hv = torch.cos(enc + self.bias) * torch.sin(enc) 
        return functional.hard_quantize(sample_hv)

    def model_update(self, x, y, cluster): # update # y = no hv
        x = torch.reshape(x, (1,d))
        model_result = F.linear(x.type(torch.FloatTensor), self.M[cluster].type(torch.FloatTensor))
        update = self.M[cluster] + (self.lr * (y - model_result) * x) # Model + alpha*(Error)*(x)
        self.M[cluster] = update[0] # New 
    
    def forward(self, x):
        enc = torch.reshape(self.encode(x), (1,d))
        similarity = cos_similarity(self.training_samples, enc)
        i = list(similarity.numpy()).index(max(similarity).numpy()[0])
        model_result = F.linear(enc, self.M[self.cluster_model.labels_[i]])
        return model_result # Return the resolutions
    
    def train(self, sets_training, matrix_1_norm, epochs):
        
        full_samples = {}
        for time, i in enumerate(sets_training):
            samples = matrix_1_norm[:, i:i+20]
            for n in range(0, samples.shape[0], 1):
                sample = torch.tensor(samples[n, :])
                full_samples[(samples.shape[0]*time) + n] = sample

        if(self.cluster_model == None):
            encoded = torch.zeros(len(full_samples), 10000)
            for i, samp in (full_samples.items()):
                encoded[i, :] = self.encode(samp)
            self.training_samples = encoded
            affinity_matrix = cos_similarity(encoded, encoded)
            clustering = SpectralClustering(n_clusters=models, assign_labels='discretize', 
                                            random_state=0, affinity='precomputed').fit(affinity_matrix)
            self.cluster_model = clustering

        for _ in range(epochs): # Number of iterations for all the samples
            pred = []
            labels_full = []
            for time, i in enumerate(sets_training):
                print(i)
                #samples = matrix_1_norm[:, i:i+40]
                labels = matrix_1_norm[:, i+20]
                
                for n in range(samples.shape[0]):
                    label = torch.tensor(labels[n])
                    item = (samples.shape[0]*time) + n
                    self.model_update(self.training_samples[item], label, self.cluster_model.labels_[item]) 
    
    def test(self, sets_testing, matrix_1_norm):
        pred = []
        labels_full = []
        for i in tqdm(sets_testing):
            samples = matrix_1_norm[:, i:i+20]
            labels = matrix_1_norm[:, i+20]
            for n in range(samples.shape[0]):
                label = torch.tensor(labels[n])
                sample = torch.tensor(samples[n, :])
                # Pass samples from test to model (forward function)
                predictions = self.forward(sample, i)
                pred.append(predictions[0])
                labels_full.append(label.unsqueeze(dim=0))
        print(f"Testing root mean squared error of {(mean_squared_error(labels_full, pred, squared=False)):.3f}")

# %%
model = MultiModel_With_NonLinear_Sin(2, 20)
model.train(sets_training, matrix_1_norm, 1)
model.test(sets_testing, matrix_1_norm)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 21 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> model = MultiModel_With_NonLinear_Sin(2, 20)
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> model.train(sets_training, matrix_1_norm, 1)
#       <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> model.test(sets_testing, matrix_1_norm)
#
# d:\Documents\Escuela\SEEL\Contextual_Aware_Encoding_test.ipynb Cell 21 in MultiModel_With_NonLinear_Sin.train(self, sets_training, matrix_1_norm, epochs)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=68'>69</a>     encoded[i, :] = self.encode(samp)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=69'>70</a> self.training_samples = encoded
# ---> <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=70'>71</a> affinity_matrix = cos_similarity(encoded, encoded)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=71'>72</a> clustering = SpectralClustering(n_clusters=models, assign_labels='discretize',
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=72'>73</a>                                 random_state=0, affinity='precomputed').fit(affinity_matrix)
#      <a href='vscode-notebook-cell:/d%3A/Documents/Escuela/SEEL/Contextual_Aware_Encoding_test.ipynb#X30sZmlsZQ%3D%3D?line=73'>74</a> self.cluster_model = clustering
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torchhd\functional.py:751, in cos_similarity(input, others)
#     749 input = as_vsa_model(input)
#     750 others = as_vsa_model(others)
# --> 751 return input.cos_similarity(others)
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torchhd\map.py:307, in MAP.cos_similarity(self, others, eps)
#     304 """Cosine similarity with other hypervectors"""
#     305 dtype = torch.get_default_dtype()
# --> 307 self_dot = torch.sum(self * self, dim=-1, dtype=dtype)
#     308 self_mag = self_dot.sqrt()
#     310 others_dot = torch.sum(others * others, dim=-1, dtype=dtype)
#
# File d:\Aplicaciones\Anaconda\envs\tensorflow_env\lib\site-packages\torch\_tensor.py:1121, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1118     return NotImplemented
#    1120 with _C.DisableTorchFunction():
# -> 1121     ret = func(*args, **kwargs)
#    1122     if func in get_default_nowrap_functions():
#    1123         return ret
#
# RuntimeError: [enforce fail at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10\core\impl\alloc_cpu.cpp:81] data. DefaultCPUAllocator: not enough memory: you tried to allocate 1592640000 bytes.
